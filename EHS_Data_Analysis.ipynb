# %% [markdown]
# <a href="https://colab.research.google.com/github/justaplan/GAS-Clasp-Gulp/blob/master/EHS_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()
import pandas as pd
import matplotlib.pyplot as plt
import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

wb = gc.open_by_key('1qvK5BkBSLDFKhausgwg8Ai3-3scVwJHGBrJ17fj48tc')
ws = wb.worksheet("Year Data")

# get_all_values gives a list of rows.
rows = ws.get_all_values()

# Convert to a DataFrame and render.
df = pd.DataFrame.from_records(rows[1:],columns=rows[0])
df.tail()
# Out:
#   No  Year  ... National Incident Rate National Fatality Rate
# 2     2016  ...                   2.88                   4.86
# 3     2017  ...                   2.93                   4.92
# 4     2018  ...                    2.4                   4.14
# 5     2019  ...                   2.71                   3.83
# 6     2020  ...                   2.71                   3.83
#
# [5 rows x 15 columns]

# %%
## Chart Size and Style
plt.figure(figsize=(20,7),dpi=100)
plt.style.use("seaborn")

x = df["Year"]
y = [float(y) for y in df["Incident Rate"]]

plt.plot(x,y)
plt.yticks([y for y in range(0,15)])
plt.show()
